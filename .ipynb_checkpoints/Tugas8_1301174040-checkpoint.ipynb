# %%
import pandas as pd
import numpy as np
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# %%
# Load in the dataframe
df = pd.read_csv("https://raw.githubusercontent.com/ahmadrefi/Tugas-8/master/trump_tweets.csv", index_col=0)

# %%
df.head()
df.drop(columns=['hashtags'])
# Out:
#                            user_name   user_location  \
# id
# 1285299379746811915  Donald J. Trump  Washington, DC
# 1285196013020610562  Donald J. Trump  Washington, DC
# 1284899438591451137  Donald J. Trump  Washington, DC
# 1284894845614600194  Donald J. Trump  Washington, DC
# 1288503660264058880  Donald J. Trump  Washington, DC
# ...                              ...             ...
# 1324139647111409667  Donald J. Trump  Washington, DC
# 1324139387546984449  Donald J. Trump  Washington, DC
# 1324130551234727936  Donald J. Trump  Washington, DC
# 1324108206801563650  Donald J. Trump  Washington, DC
# 1324108200141082624  Donald J. Trump  Washington, DC
#
#                                                      user_description  \
# id
# 1285299379746811915  45th President of the United States of America🇺🇸
# 1285196013020610562  45th President of the United States of America🇺🇸
# 1284899438591451137  45th President of the United States of America🇺🇸
# ...

# %%
stop_words = ["https", "CO"] + list(STOPWORDS)

# %%
tweets = " ".join(line for line in df['text'])

# %%
colors = ["#002868", "#BF0A30"]
colormap = LinearSegmentedColormap.from_list("mycmap", colors)
wc = WordCloud(width = 600, height = 400, random_state=1, background_color='white', colormap=colormap , collocations=True, 
               stopwords = stop_words).generate(tweets)

plt.figure(figsize=[13,13])
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
plt.show()
